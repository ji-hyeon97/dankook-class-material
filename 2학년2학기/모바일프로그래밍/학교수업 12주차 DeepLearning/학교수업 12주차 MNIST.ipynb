# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from keras.layers import Dense
from keras.models import Sequential

# %%
from keras.datasets import mnist
(X_train, Y_train), (X_test, Y_test) = mnist.load_data()
print("Training data shape : ", X_train.shape)
print("Training label shape : ", Y_train.shape)
print("Testing data shape : ", X_test.shape)
print("Testing label shape : ", Y_test.shape)
# Out:
# Training data shape :  (60000, 28, 28)
# Training label shape :  (60000,)
# Testing data shape :  (10000, 28, 28)
# Testing label shape :  (10000,)

# %%
X_train = X_train.reshape(60000, 28*28).astype('float32')/255.0
X_test = X_test.reshape(10000, 28*28).astype('float32')/255.0
Y_train = keras.utils.to_categorical(Y_train, 10)
Y_test = keras.utils.to_categorical(Y_test, 10)

# %%
model = Sequential(name='SeojihyeonMnistModel_1')
model.add(Dense(units=512, input_dim=(28*28), activation='relu',name='hidden1'))
model.add(Dense(units=24 , activation='relu',name='hidden2'))
model.add(Dense(units=10, activation='softmax',name='output'))
model.summary()
# Out:
# Model: "SeojihyeonMnistModel_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  hidden1 (Dense)             (None, 512)               401920
#
#  hidden2 (Dense)             (None, 24)                12312
#
#  output (Dense)              (None, 10)                250
#
# =================================================================
# Total params: 414,482
# Trainable params: 414,482
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(X_train, Y_train, batch_size=200, epochs=10, verbose=2, validation_split=0.3)
# Out:
# Epoch 1/10
# 210/210 - 2s - loss: 0.3686 - accuracy: 0.8967 - val_loss: 0.1776 - val_accuracy: 0.9496 - 2s/epoch - 7ms/step
# Epoch 2/10
# 210/210 - 1s - loss: 0.1364 - accuracy: 0.9598 - val_loss: 0.1330 - val_accuracy: 0.9601 - 900ms/epoch - 4ms/step
# Epoch 3/10
# 210/210 - 1s - loss: 0.0936 - accuracy: 0.9730 - val_loss: 0.1144 - val_accuracy: 0.9677 - 987ms/epoch - 5ms/step
# Epoch 4/10
# 210/210 - 1s - loss: 0.0664 - accuracy: 0.9802 - val_loss: 0.1083 - val_accuracy: 0.9692 - 994ms/epoch - 5ms/step
# Epoch 5/10
# 210/210 - 1s - loss: 0.0491 - accuracy: 0.9859 - val_loss: 0.1020 - val_accuracy: 0.9705 - 892ms/epoch - 4ms/step
# Epoch 6/10
# 210/210 - 1s - loss: 0.0377 - accuracy: 0.9895 - val_loss: 0.0951 - val_accuracy: 0.9722 - 984ms/epoch - 5ms/step
# Epoch 7/10
# 210/210 - 1s - loss: 0.0276 - accuracy: 0.9926 - val_loss: 0.0919 - val_accuracy: 0.9733 - 877ms/epoch - 4ms/step
# Epoch 8/10
# 210/210 - 1s - loss: 0.0208 - accuracy: 0.9948 - val_loss: 0.0854 - val_accuracy: 0.9759 - 979ms/epoch - 5ms/step
# Epoch 9/10
# 210/210 - 1s - loss: 0.0150 - accuracy: 0.9966 - val_loss: 0.0910 - val_accuracy: 0.9757 - 895ms/epoch - 4ms/step
# Epoch 10/10
# 210/210 - 1s - loss: 0.0132 - accuracy: 0.9972 - val_loss: 0.0976 - val_accuracy: 0.9743 - 975ms/epoch - 5ms/step

# %%
loss, accuracy = model.evaluate(X_test, Y_test)
print(f"Test loss: {loss:.3}")
print(f"Test accuracy: {accuracy:.3}")
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0818 - accuracy: 0.9755
# Test loss: 0.0818
# Test accuracy: 0.975

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['training', 'validation'], loc='best')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['training', 'validation'], loc='best')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Test accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['training', 'validation'], loc='best')
plt.show()
