# %% [markdown]
# # Google colaboratory Basics!
#
# **Basics**
# 1. Settings
# 2. Selection mode, edit mode
# 2. How to run the cell : shortcuts
# 3. Creating & deleting the cell
# 4. Code cell & Markdown(text) cell
#
# **Important**
# 1. Inserting hyperlinks
# 2. Inserting Images

# %% [markdown]
# # I. Basics

# %% [markdown]
# ## I.1. Settings!
#
# **Let's do together : Tools --> Settings**
#
# 1. Site : Theme
# 2. Editor :
#     * Editor colorization
#     * Indentation width in spaces
#     * deselect : Automatically trigger code completions
#     * select : Show line numbers
# 3. Miscellaneous(Optional) :
#     * Power level : If you want to code dynamically
#     * Corgi&Kitty mode : If you want to code peacefully

# %%
## This may be most important part

print("Hello, world!")

# %% [markdown]
# ## I.2. Selection mode, edit mode
#
# 1. Selection mode : You can see highlighted cell without any text cursor
#     * Enter : Selection mode --> Edit mode
# 2. Edit mode : You can see the text cursor
#     * Esc : Edit mode --> Selection mode

# %%
## Feel free to do it!

# %% [markdown]
# ## I.3. How to run the cell
#
# **complete the blanks below**
# 1. Ctrl + Enter : blank
# 2. Shift + Enter : blank
# 3. Alt + Enter : blank

# %%
import numpy as np
np.random.randint(0,10)

# %% [markdown]
# ## I.4. Creating & deleting the cell
#
# **write what you learn**
# 1. Ctrl + M + A : ??
# 2. Ctrl + M + B : ??
# 3. Ctrl + M + D : ?? <-- be careful

# %%
##################
## Ctrl + M + D ##
##################
for i in range(10):
    print(i)

# %%
##########################
##     Run & Debug      ##
## using stack overflow ##
##########################
for i in range(5):
    print i

# %% [markdown]
# ## I.5. Code cell & Markdown(text) cell
#
# **write what you learn**

# %%
# Ctrl + M + M

**This cell is for text**

---------------
1. you can use this
2. like this
4. some mistakes are allowed,
    * don't be afraid
    * get familiar with this syntax
```
a = 45
if a > = 40 :
    print("This part seems like code cell")
```

# %% [markdown]
# # Ctrl + M + Y
#
# a = []
# for i in range(10):
#     if i % 3 == 0 :
#         a.append(i)
# a

# %% [markdown]
# # II. Important

# %% [markdown]
# ## II.1. Inserting hyperlinks
#
# * refer to this cell to Insert a hyperlink
# * hyperlink to wherever you want
#     * recommendation : website with useful ML informations
#
# [Like this](https://www.statlearning.com/)

# %%
This cell is for hyperlink
first, change this cell into markdown cell

# %% [markdown]
# ## II.2. Inserting Images
# * refer to this cell to insert an image
# * whatever image you want
#     * recommendation : useful ML gif
#
# ![like this](https://miro.medium.com/proxy/1*tc8UF-h0nQqUfLC8-0uInQ.gif)

# %%
This cell is for Image
first, change this cell into markdown cell
